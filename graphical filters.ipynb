# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Reading Image

# %%
img=cv.imread("C:/Users/SN112/Downloads/image.jpg")

# %%
plt.imshow(im1)
plt.title('img')
plt.show()
